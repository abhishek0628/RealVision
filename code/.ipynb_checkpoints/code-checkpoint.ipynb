# %%
# !python --version
# Out:
# Python 3.10.18

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.30.0
# ipykernel        : 6.29.5
# ipywidgets       : 8.1.5
# jupyter_client   : 8.6.3
# jupyter_core     : 5.8.1
# jupyter_server   : 2.16.0
# jupyterlab       : 4.4.6
# nbclient         : 0.10.2
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.4.5
# qtconsole        : 5.6.1
# traitlets        : 5.14.3

# %%
# !pip install --user datasets transformers torch torchvision torchaudio \
ultralytics opencv-python matplotlib numpy seaborn pandas tqdm \
scikit-learn huggingface_hub
# Out:
# Requirement already satisfied: datasets in /Users/abhishekkumar/.local/lib/python3.10/site-packages (4.1.0)
# Requirement already satisfied: transformers in /Users/abhishekkumar/.local/lib/python3.10/site-packages (4.56.1)
# Requirement already satisfied: torch in /Users/abhishekkumar/.local/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: torchvision in /Users/abhishekkumar/.local/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: torchaudio in /Users/abhishekkumar/.local/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: ultralytics in /Users/abhishekkumar/.local/lib/python3.10/site-packages (8.3.200)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (3.10.5)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: seaborn in /Users/abhishekkumar/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: huggingface_hub in /Users/abhishekkumar/.local/lib/python3.10/site-packages (0.34.5)
# Requirement already satisfied: filelock in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from transformers) (2025.9.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from huggingface_hub) (1.1.10)
# Requirement already satisfied: sympy>=1.13.3 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from ultralytics) (1.33.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.7)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (5.8.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (7.4.5)
# Requirement already satisfied: tornado in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (6.5.1)
# Requirement already satisfied: traitlets>=4.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (6.0.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (78.1.1)
# Requirement already satisfied: jupyter-server in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.16.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from mistune<4,>=2.0.3->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.15.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.3.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (26.2.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.25.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.22.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.4.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.25)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (8.30.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (24.11.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.9.0.20250822)
# Requirement already satisfied: executing in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade jupyter notebook
# Out:
# Requirement already satisfied: jupyter in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (7.4.5)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter) (4.4.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from notebook) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab->jupyter) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.25.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (8.30.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert->jupyter) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20250822)
# Requirement already satisfied: executing in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade ipywidgets
# !jupyter nbextension enable --py widgetsnbextension
#!jupyter notebook stop
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (8.1.5)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.0 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: widgetsnbextension, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.13
#     Uninstalling widgetsnbextension-4.0.13:
#       Successfully uninstalled widgetsnbextension-4.0.13
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.5
#     Uninstalling ipywidgets-8.1.5:
#       Successfully uninstalled ipywidgets-8.1.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ipywidgets]
# Successfully installed ipywidgets-8.1.7 widgetsnbextension-4.0.14
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# qtconsole run server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
# !pip install datasets huggingface_hub opencv-python matplotlib
# Out:
# Requirement already satisfied: datasets in /Users/abhishekkumar/.local/lib/python3.10/site-packages (4.1.0)
# Requirement already satisfied: huggingface_hub in /Users/abhishekkumar/.local/lib/python3.10/site-packages (0.34.5)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (3.10.5)
# Requirement already satisfied: filelock in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (2.0.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from huggingface_hub) (1.1.10)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.7)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pandas->datasets) (2025.2)

# %%
import os

print("Current Directory:", os.getcwd())  # Check where Jupyter is running

# List folders/files in the current directory
print("\nContents of Current Directory:")
print(os.listdir(os.getcwd()))
# Out:
# Current Directory: /Users/abhishekkumar/Desktop/RealVision/code
#
# Contents of Current Directory:
# ['.DS_Store', 'code.ipynb']

# %%
import os
from datasets import Dataset

# Set the dataset folder correctly
dataset_path = os.path.abspath("created")  # 'created' is inside the current directory

# Verify if the folder exists
if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"❌ The folder '{dataset_path}' does not exist. Check the correct path.")

# Get all image file paths
image_files = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Ensure there are images
if not image_files:
    raise ValueError("❌ No images found in the 'created' folder.")

# Convert to Hugging Face dataset
dataset = Dataset.from_dict({"image_path": image_files})

print(f"✅ Successfully loaded {len(dataset)} images from '{dataset_path}'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 9
#       7 # Verify if the folder exists
#       8 if not os.path.exists(dataset_path):
# ----> 9     raise FileNotFoundError(f"❌ The folder '{dataset_path}' does not exist. Check the correct path.")
#      11 # Get all image file paths
#      12 image_files = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if f.endswith(('.jpg', '.png', '.jpeg'))]
#
# FileNotFoundError: ❌ The folder '/Users/abhishekkumar/Desktop/RealVision/code/created' does not exist. Check the correct path.

# %%
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# Display the first 10 images
fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # 2 rows × 5 columns grid

for i, ax in enumerate(axes.flat):  
    image_path = dataset[i]["image_path"]  # Get the image file path
    image = Image.open(image_path)  # Open the image using PIL
    
    ax.imshow(image)  # Show the image
    ax.axis("off")  # Hide axes
    ax.set_title(f"Image {i+1}")  # Set title

plt.tight_layout()  # Adjust layout
plt.show()  # Display images
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       6 fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # 2 rows × 5 columns grid
#       8 for i, ax in enumerate(axes.flat):
# ----> 9     image_path = dataset[i]["image_path"]  # Get the image file path
#      10     image = Image.open(image_path)  # Open the image using PIL
#      12     ax.imshow(image)  # Show the image
#
# NameError: name 'dataset' is not defined

# %%
import os
dataset_folder = "created"
print("Contents of Dataset Folder:", os.listdir(dataset_folder))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 import os
#       2 dataset_folder = "created"
# ----> 3 print("Contents of Dataset Folder:", os.listdir(dataset_folder))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'created'

# %%
from PIL import Image
import numpy as np

# Define the target size
target_size = (224, 224)

def preprocess_image(image_path):
    # Open the image file
    image = Image.open(image_path)
    
    # Resize the image to the target size
    image = image.resize(target_size)
    
    # Convert image to numpy array and normalize
    image_array = np.array(image) / 255.0  # Normalize to [0, 1]
    
    return image_array

# Apply preprocessing to all images
processed_images = [preprocess_image(image_path) for image_path in dataset["image_path"]]

print(f"✅ Preprocessed {len(processed_images)} images.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 20
#      17     return image_array
#      19 # Apply preprocessing to all images
# ---> 20 processed_images = [preprocess_image(image_path) for image_path in dataset["image_path"]]
#      22 print(f"✅ Preprocessed {len(processed_images)} images.")
#
# NameError: name 'dataset' is not defined

# %%
import cv2
import numpy as np

def preprocess_image(image_path, target_size=(640, 640)):
    """
    Preprocess the image: resize and normalize.
    """
    # Read the image
    image = cv2.imread(image_path)

    # Resize the image
    image = cv2.resize(image, target_size)

    # Normalize the image
    image = image / 255.0  # Normalize to [0, 1]

    return image

# Example preprocessing of the first image in the dataset
image_path = dataset[0]["image_path"]
processed_image = preprocess_image(image_path)

# Display preprocessed image
plt.imshow(processed_image)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 20
#      17     return image
#      19 # Example preprocessing of the first image in the dataset
# ---> 20 image_path = dataset[0]["image_path"]
#      21 processed_image = preprocess_image(image_path)
#      23 # Display preprocessed image
#
# NameError: name 'dataset' is not defined

# %%
# !python -m venv yolov5_env

# %%
# !pip install torch torchvision --user
# !pip install yolov5 --user
# Out:
# Requirement already satisfied: torch in /Users/abhishekkumar/.local/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: torchvision in /Users/abhishekkumar/.local/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: filelock in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Collecting yolov5
#   Downloading yolov5-7.0.14-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# Requirement already satisfied: gitpython>=3.1.30 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (3.1.45)
# Requirement already satisfied: matplotlib>=3.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (3.10.5)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (2.0.1)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (4.12.0.88)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (11.3.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (1.15.3)
# Collecting thop>=0.1.1 (from yolov5)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.7.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from yolov5) (2.8.0)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from yolov5) (0.23.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (4.67.1)
# Requirement already satisfied: ultralytics>=8.0.100 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from yolov5) (8.3.200)
# Collecting tensorboard>=2.4.1 (from yolov5)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (2.3.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from yolov5) (0.13.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from yolov5) (78.1.1)
# Collecting fire (from yolov5)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting boto3>=1.19.1 (from yolov5)
#   Downloading boto3-1.40.31-py3-none-any.whl.metadata (6.7 kB)
# Collecting sahi>=0.11.10 (from yolov5)
#   Downloading sahi-0.11.34-py3-none-any.whl.metadata (18 kB)
# Collecting huggingface-hub<0.25.0,>=0.12.0 (from yolov5)
#   Downloading huggingface_hub-0.24.7-py3-none-any.whl.metadata (13 kB)
# Collecting roboflow>=0.2.29 (from yolov5)
#   Downloading roboflow-1.2.9-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: filelock in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (25.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (4.15.0)
# Collecting botocore<1.41.0,>=1.40.31 (from boto3>=1.19.1->yolov5)
#   Downloading botocore-1.40.31-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.19.1->yolov5)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3>=1.19.1->yolov5)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.31->boto3>=1.19.1->yolov5) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.31->boto3>=1.19.1->yolov5) (2.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.31->boto3>=1.19.1->yolov5) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from gitpython>=3.1.30->yolov5) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pandas>=1.1.4->yolov5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from pandas>=1.1.4->yolov5) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.23.0->yolov5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.23.0->yolov5) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from requests>=2.23.0->yolov5) (2025.8.3)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow>=0.2.29->yolov5)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow>=0.2.29->yolov5)
#   Downloading pi_heif-1.1.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow>=0.2.29->yolov5)
#   Downloading pillow_avif_plugin-1.5.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting python-dotenv (from roboflow>=0.2.29->yolov5)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting requests-toolbelt (from roboflow>=0.2.29->yolov5)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow>=0.2.29->yolov5)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5) (8.2.1)
# Collecting opencv-python>=4.1.1 (from yolov5)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting shapely>=2.0.0 (from sahi>=0.11.10->yolov5)
#   Downloading shapely-2.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->yolov5)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.4.1->yolov5)
#   Downloading grpcio-1.74.0-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.4.1->yolov5)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5) (6.32.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.4.1->yolov5)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.4.1->yolov5)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sympy>=1.13.3 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from torch>=1.7.0->yolov5) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch>=1.7.0->yolov5) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from torch>=1.7.0->yolov5) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.7.0->yolov5) (1.3.0)
# Requirement already satisfied: polars in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from ultralytics>=8.0.100->yolov5) (1.33.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/abhishekkumar/.local/lib/python3.10/site-packages (from ultralytics>=8.0.100->yolov5) (2.0.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/ai-search/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (3.0.2)
# Collecting termcolor (from fire->yolov5)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading yolov5-7.0.14-py37.py38.py39.py310-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.5/953.5 kB 223.1 kB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.24.7-py3-none-any.whl (417 kB)
# Downloading boto3-1.40.31-py3-none-any.whl (139 kB)
# Downloading botocore-1.40.31-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 1.6 MB/s eta 0:00:00a 0:00:01m
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Downloading roboflow-1.2.9-py3-none-any.whl (88 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading pi_heif-1.1.0-cp310-cp310-macosx_14_0_arm64.whl (642 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.4/642.4 kB 35.5 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading sahi-0.11.34-py3-none-any.whl (111 kB)
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 8.6 MB/s eta 0:00:0000:0100:01
# Downloading shapely-2.1.1-cp310-cp310-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.2 MB/s eta 0:00:00ta 0:00:01
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 5.1 MB/s eta 0:00:00a 0:00:01m
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading grpcio-1.74.0-cp310-cp310-macosx_11_0_universal2.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 7.2 MB/s eta 0:00:00a 0:00:01
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: pillow-avif-plugin, filetype, werkzeug, terminaltables, termcolor, tensorboard-data-server, shapely, python-dotenv, pybboxes, pi-heif, opencv-python-headless, opencv-python, markdown, jmespath, grpcio, absl-py, tensorboard, requests-toolbelt, huggingface-hub, fire, botocore, thop, sahi, s3transfer, roboflow, boto3, yolov5
#   WARNING: The script filetype is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/27 [shapely]  WARNING: The script dotenv is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 11/27 [opencv-python]headless]  WARNING: The script markdown_py is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 16/27 [tensorboard]  WARNING: The script tensorboard is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.34.5━━━━━━━ 16/27 [tensorboard]
#     Uninstalling huggingface-hub-0.34.5:m━━━━━━━━━━━━━━━━ 16/27 [tensorboard]
#       Successfully uninstalled huggingface-hub-0.34.5━━━━━━━━━ 16/27 [tensorboard]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 18/27 [huggingface-hub]  WARNING: The script huggingface-cli is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 22/27 [sahi]  WARNING: The script sahi is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script roboflow is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 26/27 [yolov5]  WARNING: The script yolov5 is installed in '/Users/abhishekkumar/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [yolov5]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.56.1 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 0.24.7 which is incompatible.
# Successfully installed absl-py-2.3.1 boto3-1.40.31 botocore-1.40.31 filetype-1.2.0 fire-0.7.1 grpcio-1.74.0 huggingface-hub-0.24.7 jmespath-1.0.1 markdown-3.9 opencv-python-4.11.0.86 opencv-python-headless-4.10.0.84 pi-heif-1.1.0 pillow-avif-plugin-1.5.2 pybboxes-0.1.6 python-dotenv-1.1.1 requests-toolbelt-1.0.0 roboflow-1.2.9 s3transfer-0.14.0 sahi-0.11.34 shapely-2.1.1 tensorboard-2.20.0 tensorboard-data-server-0.7.2 termcolor-3.1.0 terminaltables-3.1.10 thop-0.1.1.post2209072238 werkzeug-3.1.3 yolov5-7.0.14

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*torch.cuda.amp.autocast.*")

import matplotlib.pyplot as plt
from PIL import Image

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # Load YOLOv5 small model

# Function to run object detection on an image
def detect_objects(image_path):
    # Load the image
    img = Image.open(image_path)

    # Perform inference
    results = model(img)  # Perform inference on the image

    # Render results
    results.render()  # Draw bounding boxes and labels directly on the image

    # Display the image with detected objects
    plt.imshow(results.ims[0])  # Use 'ims' instead of 'imgs' to access the image with detections
    plt.axis("off")
    plt.show()

# Run detection on the first image in your dataset
detect_objects(dataset[0]["image_path"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       5 from PIL import Image
#       7 # Load YOLOv5 model
# ----> 8 model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # Load YOLOv5 small model
#      10 # Function to run object detection on an image
#      11 def detect_objects(image_path):
#      12     # Load the image
#
# NameError: name 'torch' is not defined

# %%
# Function to detect and save results for all images
def detect_all_objects(dataset):
    for i, data in enumerate(dataset):
        image_path = data["image_path"]
        img = Image.open(image_path)
        
        # Perform inference on the image
        results = model(img)
        
        # Render results (bounding boxes and labels on the image)
        results.render()
        
        # Save the output image
        output_image_path = f"output_image_{i+1}.png"
        Image.fromarray(results.ims[0]).save(output_image_path)
        
        print(f"Saved detection results for image {i+1} to {output_image_path}")

# Run object detection on all images
detect_all_objects(dataset)

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

# Path where your output images are saved
output_dir = "output"

# Get all output image filenames
output_image_files = [f for f in os.listdir(output_dir) if f.endswith(".png")]

# Display first 10 images in a 2x5 grid layout
fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # 2 rows × 5 columns grid

for i, ax in enumerate(axes.flat):
    if i < len(output_image_files):  # Ensure we don't exceed the number of saved images
        # Load the image
        image_path = os.path.join(output_dir, output_image_files[i])
        image = Image.open(image_path)
        
        # Display the image
        ax.imshow(image)
        ax.axis("off")  # Hide axes
        ax.set_title(f"Image {i+1}")  # Set title

# Adjust layout
plt.tight_layout()
plt.show()  # Display images

# %%
pip install opencv-python-headless

# %%
import cv2
import torch
import os
import matplotlib.pyplot as plt

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # Load YOLOv5 small model

# Create output directory if not exists
output_dir = "output_video"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Path to your video file
video_path = r'C:\Users\Lenovo\Desktop\MFML_project\MFML_project\video.mp4'  # Replace with your video file path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video is opened correctly
if not cap.isOpened():
    print("❌ Error: Could not open video.")
    exit()

frame_count = 0  # Initialize frame counter

# Process video frames
while cap.isOpened():
    ret, frame = cap.read()  # Capture each frame
    if not ret:
        break
    
    # Perform inference on the frame
    results = model(frame)

    # Render results (bounding boxes and labels on the image)
    results.render()

    # Display the frame with detections
    plt.imshow(results.ims[0])  # Rendered frame
    plt.axis('off')  # Hide axes
    plt.show()

    # Convert frame to BGR for saving
    frame_bgr = cv2.cvtColor(results.ims[0], cv2.COLOR_RGB2BGR)

    # Save the detected frame to output directory
    frame_count += 1
    output_image_path = os.path.join(output_dir, f"frame_{frame_count}.png")
    cv2.imwrite(output_image_path, frame_bgr)
    print(f"Saved frame {frame_count} to {output_image_path}")

# Release the video and close OpenCV windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import torch
import os

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # Load YOLOv5 small model

# Create output directory if not exists
output_dir = "output_video"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Path to your video file
video_path = r'C:\Users\Lenovo\Desktop\MFML_project\MFML_project\video.mp4'  # Replace with your video file path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video is opened correctly
if not cap.isOpened():
    print("❌ Error: Could not open video.")
    exit()

# Get the video frame width, height, and FPS for creating the output video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Create a VideoWriter object to save the output video
output_video_path = os.path.join(output_dir, 'result.mp4')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Video codec for .mp4 format
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

frame_count = 0  # Initialize frame counter

# Process video frames
while cap.isOpened():
    ret, frame = cap.read()  # Capture each frame
    if not ret:
        break
    
    # Perform inference on the frame
    results = model(frame)

    # Render results (bounding boxes and labels on the image)
    results.render()

    # Convert the results image to BGR for saving (OpenCV uses BGR)
    frame_bgr = cv2.cvtColor(results.ims[0], cv2.COLOR_RGB2BGR)

    # Write the processed frame to the output video
    out.write(frame_bgr)
    frame_count += 1
    print(f"Processing frame {frame_count}...")

# Release the video capture and writer objects
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"✅ Processed video saved as {output_video_path}")
